# %% [markdown]
# This notebooks aims at visualizing the structures of clusters of different sets of natural products

# %%
# Import myfunc at cix folder
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../cix')
import myfuncs as mf
import pandas as pd
from rdkit import Chem
from rdkit import rdBase
rdBase.DisableLog('rdApp.*') # To make rdkit silent
from rdkit.Chem import PandasTools as pt
from rdkit.Chem import Descriptors
import numpy as np
import time
# Out:
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: The mpl_toolkits.axes_grid module was deprecated in version 2.1. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist provies the same functionality instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
##############################################################################
## Input molecules
##############################################################################

d = pd.read_csv("./nppurg2.csv")
smis = list(d["smi"])
ncorr, n, smis, wrongsmis = mf.corrsmis(smis)
smidf = mf.smis2smidf(smis)
cls = mf.clusmidf(smidf)
# Out:
# Clustering time: 00:03:48

# %%
cl_smis_in = []
for i in range(10):
    cl = cls[i]
    smis = [smidf.loc[smidf["id"] == i, "smiles"].iloc[0] for i in cl]
    cl_smis_in.append(smis)

# %%
mf.paintmols(cl_smis_in[0])
# Out:
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/rdkit/Chem/Draw/IPythonConsole.py:172: UserWarning: Truncating the list of molecules to be displayed to 50. Change the maxMols value to display more.
#   warnings.warn("Truncating the list of molecules to be displayed to %d. Change the maxMols value to display more."%(maxMols))
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=750x1500 at 0x7F9D59198190>

# %%
##############################################################################
## Output Unconditioned molecules
##############################################################################

d = pd.read_csv("./unc81661.smi", header = None, names = ["smiles"])
smis = list(d["smiles"])
ncorr, n, smis, wrongsmis = mf.corrsmis(smis)
smidf = mf.smis2smidf(smis)
cls = mf.clusmidf(smidf)
# Out:
# Clustering time: 00:00:11

# %%
smis = list(d["smi"])
ncorr, n, smis, wrongsmis = mf.corrsmis(smis)
smidf = mf.smis2smidf(smis)
cls = mf.clusmidf(smidf)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-ed3a179a4252> in <module>()
# ----> 1 smis = list(d["smi"])
#       2 ncorr, n, smis, wrongsmis = mf.corrsmis(smis)
#       3 smidf = mf.smis2smidf(smis)
#       4 cls = mf.clusmidf(smidf)
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'smi'

# %%
cl_smis_un = []
for i in range(10):
    cl = cls[i]
    smis = [smidf.loc[smidf["id"] == i, "smiles"].iloc[0] for i in cl]
    cl_smis_un.append(smis)

# %%
mf.paintmols(cl_smis_un[0])

# %%
##############################################################################
## Output Conditioned molecules
##############################################################################

d = pd.read_csv("./con81661.smi", header = None, names = ["smiles"])
smis = list(d["smiles"])
ncorr, n, smis, wrongsmis = mf.corrsmis(smis)
# uniquify
smis = list(set(smis))
smidf = mf.smis2smidf(smis)
cls = mf.clusmidf(smidf)

# %%
cl_smis_co = []
for i in range(10):
    cl = cls[i]
    smis = [smidf.loc[smidf["id"] == i, "smiles"].iloc[0] for i in cl]
    cl_smis_co.append(smis)

# %%
mf.paintmols(cl_smis_co[9])
