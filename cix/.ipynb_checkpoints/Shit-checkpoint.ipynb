# %%
import chemfp
from chemfp import search
import bclus
import pandas as pd
import time
import sys

# %%
# Import SMILES into a dataframe

smi = pd.read_csv('../data/z310k.smi', delim_whitespace = True, names = ['smiles','id'], header = None)

# %%
# Generate RDKit FPs

import subprocess as sp

start = time.time()

sp.call(['rdkit2fps', '../data/z310k.smi', '-o', 'z310k.fps'])

end = time.time()

elapsed_time = end - start
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:09:43

# %%
# Load the FPs into an arena

try:
    arena = chemfp.load_fingerprints('./z310k.fps')
except IOError as err:
    sys.stderr.write("Cannot open fingerprint file: %s" % (err,))
    raise SystemExit(2)

# %%
# Generate the similarity table
start = time.time()

similarity_table = search.threshold_tanimoto_search_symmetric(arena, threshold = 0.8)

end = time.time()

elapsed_time = end - start
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:01:26

# %%
# Cluster the data

clus_res = bclus.taylor_butina_cluster(similarity_table)

# %%
# Generate dataframe with results

cldf = pd.DataFrame(columns = ['clid','id','centryn','smiles'])

# %%
start = time.time()

i = 0

for clid in range(len(clus_res.clusters)):
    cent_id = clus_res.clusters[clid][0] 
    line = pd.DataFrame([[clid+1, cent_id, 1, 'cc']], columns = ['clid','id','centryn','smiles'])
    cldf = pd.concat([cldf, line]) 
    i = i+1
    mems = list(clus_res.clusters[clid][1])
    for mem in mems:
        line = pd.DataFrame([[clid+1, mem, 0, 'cc1']], columns = ['clid','id','centryn','smiles'])
        cldf = pd.concat([cldf, line])
        i = i+1
        
end = time.time()

elapsed_time = end - start
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-228-1a17693ce94f> in <module>()
#       9     for mem in mems:
#      10         line = pd.DataFrame([[clid+1, mem, 0, 'cc1']], columns = ['clid','id','centryn','smiles'])
# ---> 11         cldf = pd.concat([cldf, line])
#      12         i = i+1
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/reshape/concat.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/reshape/concat.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     287
#     288             # consolidate
# --> 289             obj._consolidate(inplace=True)
#     290             ndims.add(obj.ndim)
#     291
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/generic.pyc in _consolidate(self, inplace)
#    4455         inplace = validate_bool_kwarg(inplace, 'inplace')
#    4456         if inplace:
# -> 4457             self._consolidate_inplace()
#    4458         else:
#    4459             f = lambda: self._data.consolidate()
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/generic.pyc in _consolidate_inplace(self)
#    4437             self._data = self._data.consolidate()
#    4438
# -> 4439         self._protect_consolidate(f)
#    4440
#    4441     def _consolidate(self, inplace=False):
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/generic.pyc in _protect_consolidate(self, f)
#    4426         """
#    4427         blocks_before = len(self._data.blocks)
# -> 4428         result = f()
#    4429         if len(self._data.blocks) != blocks_before:
#    4430             self._clear_item_cache()
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/generic.pyc in f()
#    4435
#    4436         def f():
# -> 4437             self._data = self._data.consolidate()
#    4438
#    4439         self._protect_consolidate(f)
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/internals.pyc in consolidate(self)
#    4096         bm = self.__class__(self.blocks, self.axes)
#    4097         bm._is_consolidated = False
# -> 4098         bm._consolidate_inplace()
#    4099         return bm
#    4100
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/internals.pyc in _consolidate_inplace(self)
#    4101     def _consolidate_inplace(self):
#    4102         if not self.is_consolidated():
# -> 4103             self.blocks = tuple(_consolidate(self.blocks))
#    4104             self._is_consolidated = True
#    4105             self._known_consolidated = True
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/internals.pyc in _consolidate(blocks)
#    5067     for (_can_consolidate, dtype), group_blocks in grouper:
#    5068         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 5069                                       _can_consolidate=_can_consolidate)
#    5070         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    5071     return new_blocks
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/internals.pyc in _merge_blocks(blocks, dtype, _can_consolidate)
#    5087         # combination of those slices is a slice, too.
#    5088         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
# -> 5089         new_values = _vstack([b.values for b in blocks], dtype)
#    5090
#    5091         argsort = np.argsort(new_mgr_locs)
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/internals.pyc in _vstack(to_stack, dtype)
#    5133
#    5134     else:
# -> 5135         return np.vstack(to_stack)
#    5136
#    5137
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/numpy/core/shape_base.pyc in vstack(tup)
#     232
#     233     """
# --> 234     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     235
#     236 def hstack(tup):
#
# KeyboardInterrupt:

# %%
pd.DataFrame([[clid+1, mem, 0, 'cc1']], columns = ['clid','id','centryn','smiles'])
# Out:
#    clid      id  centryn smiles
# 0     3  147454        0    cc1

# %%
cldf
# Out:
#    clid      id centryn smiles
# 0     1  176706       1     cc
# 0     1  167078       0    cc1
# 0     1  187051       0    cc1
# 0     1  239958       0    cc1
# 0     1  213002       0    cc1
# 0     1  193197       0    cc1
# 0     1  172049       0    cc1
# 0     1  215058       0    cc1
# 0     1  184340       0    cc1
# 0     1  213016       0    cc1
# 0     1  181822       0    cc1
# 0     1  188442       0    cc1
# 0     1  192175       0    cc1
# 0     1  167965       0    cc1
# 0     1  241694       0    cc1
# 0     1  187948       0    cc1
# 0     1  198041       0    cc1
# 0     1  192548       0    cc1
# 0     1  198697       0    cc1
# 0     1  192554       0    cc1
# 0     1  181255       0    cc1
# 0     1  213036       0    cc1
# 0     1  200751       0    cc1
# 0     1  194608       0    cc1
# 0     1  184372       0    cc1
# 0     1  172085       0    cc1
# 0     1  192567       0    cc1
# 0     1  172096       0    cc1
# 0     1  213344       0    cc1
# 0     1  235589       0    cc1
# ..  ...     ...     ...    ...
# 0     3  239522       0    cc1
# 0     3  202662       0    cc1
# 0     3  190378       0    cc1
# 0     3  200619       0    cc1
# 0     3  175711       0    cc1
# 0     3  212911       0    cc1
# 0     3  182192       0    cc1
# 0     3  184246       0    cc1
# 0     3  174409       0    cc1
# 0     3  194491       0    cc1
# 0     3  194495       0    cc1
# 0     3  157632       0    cc1
# 0     3  180161       0    cc1
# 0     3  186310       0    cc1
# 0     3  208841       0    cc1
# 0     3  210890       0    cc1
# 0     3  214989       0    cc1
# 0     3  219086       0    cc1
# 0     3  174034       0    cc1
# 0     3  227285       0    cc1
# 0     3  215007       0    cc1
# 0     3  137187       0    cc1
# 0     3  182249       0    cc1
# 0     3  186350       0    cc1
# 0     3  186354       0    cc1
# 0     3  145406       0    cc1
# 0     3  223222       0    cc1
# 0     3  206842       0    cc1
# 0     3  195583       0    cc1
# 0     3  147454       0    cc1
#
# [1650 rows x 4 columns]

# %%
cldf.iloc[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-162-c3fc7cb2fc69> in <module>()
# ----> 1 cldf.iloc[1]
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    2100
#    2101             # validate the location
# -> 2102             self._validate_integer(key, axis)
#    2103
#    2104             return self._get_loc(key, axis=axis)
#
# /home/gcolmenarejo/anaconda3/envs/cix/lib/python2.7/site-packages/pandas/core/indexing.pyc in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds
